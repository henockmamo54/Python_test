# %%
import tensorflow as tf
from tensorflow import keras 
import os 
import pandas as pd
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras import *
from tensorflow.keras import layers

# %% [markdown]
# read the files under /image direcory and sort by the time value.

# %%
images_name= os.listdir("./images")

rename=lambda x : (int)(x.replace('prb-heat-map-','').split('-')[0])+ (int)(x.replace('prb-heat-map-','').split('-')[1].replace('.png',''))/10
modified_name=[rename(x) for x in images_name]

data= pd .DataFrame()
data["FileName"]= images_name
data["SequenceNumber"]= modified_name
data=data.sort_values(by=["SequenceNumber"]).reset_index(drop=True)
data["Good"]=1 # to track the goodness of the image or to idnetify if there is error reading the image

# %% [markdown]
# Generate sample gif file

# %%
# imgs = (Image.open("./images/"+f) for f in data.FileName[:25])
# img = next(imgs)  # extract first image from iterator
# img.save(fp='images.gif', format='GIF', append_images=imgs,
#          save_all=True, duration=200, loop=0)

# %%
all_images=[]
for i in range(data.shape[0]):
    try:
        print("Reading data ", i)
        temp = np.array(Image.open('./images/'+data.FileName[i]).resize((300,300)))[:,:,1]
        all_images.append(temp)
#         
    except Exception as e:
        print("error",e)
        data[i,"Good"]=0
        continue
# Out:
# Reading data  0
# Reading data  1
# Reading data  2
# Reading data  3
# Reading data  4
# Reading data  5
# Reading data  6
# Reading data  7
# Reading data  8
# Reading data  9
# Reading data  10
# Reading data  11
# Reading data  12
# Reading data  13
# Reading data  14
# Reading data  15
# Reading data  16
# Reading data  17
# Reading data  18
# Reading data  19
# Reading data  20
# Reading data  21
# Reading data  22
# Reading data  23
# Reading data  24
# Reading data  25
# Reading data  26
# Reading data  27
# Reading data  28
# Reading data  29
# Reading data  30
# Reading data  31
# Reading data  32
# Reading data  33
# Reading data  34
# Reading data  35
# Reading data  36
# Reading data  37
# Reading data  38
# Reading data  39
# Reading data  40
# Reading data  41
# Reading data  42
# Reading data  43
# Reading data  44
# Reading data  45
# Reading data  46
# Reading data  47
# Reading data  48
# Reading data  49
# Reading data  50
# Reading data  51
# Reading data  52
# Reading data  53
# Reading data  54
# Reading data  55
# Reading data  56
# Reading data  57
# Reading data  58
# Reading data  59
# Reading data  60
# Reading data  61
# Reading data  62
# Reading data  63
# Reading data  64
# Reading data  65
# Reading data  66
# Reading data  67
# Reading data  68
# Reading data  69
# Reading data  70
# Reading data  71
# Reading data  72
# Reading data  73
# Reading data  74
# Reading data  75
# Reading data  76
# Reading data  77
# Reading data  78
# Reading data  79
# Reading data  80
# Reading data  81
# Reading data  82
# Reading data  83
# Reading data  84
# Reading data  85
# Reading data  86
# Reading data  87
# Reading data  88
# Reading data  89
# Reading data  90
# Reading data  91
# Reading data  92
# Reading data  93
# Reading data  94
# Reading data  95
# Reading data  96
# Reading data  97
# Reading data  98
# Reading data  99
# Reading data  100
# Reading data  101
# Reading data  102
# Reading data  103
# Reading data  104
# Reading data  105
# Reading data  106
# Reading data  107
# Reading data  108
# Reading data  109
# Reading data  110
# Reading data  111
# Reading data  112
# Reading data  113
# Reading data  114
# Reading data  115
# Reading data  116
# Reading data  117
# Reading data  118
# Reading data  119
# Reading data  120
# Reading data  121
# Reading data  122
# Reading data  123
# Reading data  124
# Reading data  125
# Reading data  126
# Reading data  127
# Reading data  128
# Reading data  129
# Reading data  130
# Reading data  131
# Reading data  132
# Reading data  133
# Reading data  134
# Reading data  135
# Reading data  136
# Reading data  137
# Reading data  138
# Reading data  139
# Reading data  140
# Reading data  141
# Reading data  142
# Reading data  143
# Reading data  144
# Reading data  145
# Reading data  146
# Reading data  147
# Reading data  148
# Reading data  149
# Reading data  150
# Reading data  151
# Reading data  152
# Reading data  153
# Reading data  154
# Reading data  155
# Reading data  156
# Reading data  157
# Reading data  158
# Reading data  159
# Reading data  160
# Reading data  161
# Reading data  162
# Reading data  163
# Reading data  164
# Reading data  165
# Reading data  166
# Reading data  167
# Reading data  168
# Reading data  169
# Reading data  170
# Reading data  171
# Reading data  172
# Reading data  173
# Reading data  174
# Reading data  175
# Reading data  176
# Reading data  177
# Reading data  178
# Reading data  179
# Reading data  180
# Reading data  181
# Reading data  182
# Reading data  183
# Reading data  184
# Reading data  185
# Reading data  186
# Reading data  187
# Reading data  188
# Reading data  189
# Reading data  190
# Reading data  191
# Reading data  192
# Reading data  193
# Reading data  194
# Reading data  195
# Reading data  196
# Reading data  197
# Reading data  198
# Reading data  199
# Reading data  200
# Reading data  201
# Reading data  202
# Reading data  203
# Reading data  204
# Reading data  205
# Reading data  206
# Reading data  207
# Reading data  208
# Reading data  209
# error image file is truncated
# Reading data  210
# Reading data  211
# Reading data  212
# Reading data  213
# Reading data  214
# Reading data  215
# Reading data  216
# Reading data  217
# Reading data  218
# Reading data  219
# Reading data  220
# Reading data  221
# Reading data  222
# Reading data  223
# Reading data  224
# Reading data  225
# Reading data  226
# Reading data  227
# Reading data  228
# Reading data  229
# Reading data  230
# Reading data  231
# Reading data  232
# Reading data  233
# Reading data  234
# Reading data  235
# Reading data  236
# Reading data  237
# Reading data  238
# Reading data  239
# Reading data  240
# Reading data  241
# Reading data  242
# Reading data  243
# Reading data  244
# Reading data  245
# Reading data  246
# Reading data  247
# Reading data  248
# Reading data  249
# Reading data  250
# Reading data  251
# Reading data  252
# Reading data  253
# Reading data  254
# Reading data  255
# Reading data  256
# Reading data  257
# Reading data  258
# Reading data  259
# Reading data  260
# Reading data  261
# Reading data  262
# Reading data  263
# Reading data  264
# Reading data  265
# Reading data  266
# Reading data  267
# Reading data  268
# Reading data  269
# Reading data  270
# Reading data  271
# Reading data  272
# Reading data  273
# Reading data  274
# Reading data  275
# Reading data  276
# Reading data  277
# Reading data  278
# Reading data  279
# Reading data  280
# Reading data  281
# Reading data  282
# Reading data  283
# Reading data  284
# Reading data  285
# Reading data  286
# Reading data  287
# Reading data  288
# Reading data  289
# Reading data  290
# Reading data  291
# Reading data  292
# Reading data  293
# Reading data  294
# Reading data  295
# Reading data  296
# Reading data  297
# Reading data  298
# Reading data  299
# Reading data  300
# Reading data  301
# Reading data  302
# Reading data  303
# Reading data  304
# Reading data  305
# Reading data  306
# Reading data  307
# Reading data  308
# Reading data  309
# Reading data  310
# Reading data  311
# Reading data  312
# Reading data  313
# Reading data  314
# Reading data  315
# Reading data  316
# Reading data  317
# Reading data  318
# Reading data  319
# Reading data  320
# Reading data  321
# Reading data  322
# Reading data  323
# Reading data  324
# Reading data  325
# Reading data  326
# Reading data  327
# Reading data  727
# Reading data  728
# Reading data  729
# Reading data  730
# Reading data  731
# Reading data  732
# Reading data  733
# Reading data  734
# Reading data  735
# Reading data  736
# Reading data  737
# Reading data  738
# Reading data  739
# Reading data  740
# Reading data  741
# Reading data  742
# Reading data  743

# %%
all_images[0].shape
# Out:
# (300, 300)

# %%
# training_x=[]
# training_y=[]
# window=20

# for iter in range(0,589):
#   print("Preparing training data ", iter)
#   trining_data_temp=np.array(Image.open('./images/'+data.FileName[iter]))[:,:,1]
#   for i in range(1,window):
#     temp = np.array(Image.open('./images/'+data.FileName[i+iter]))[:,:,1]
#     trining_data_temp=np.concatenate([temp,trining_data_temp],axis=1)

#   training_x.append(trining_data_temp)
#   training_y.append(np.array(Image.open('./images/'+data.FileName[i+1+iter]))[:,:,1])

# %%
training_x=[]
training_y=[]
window=20

for i in range(len(all_images)-1-window):
    temp=np.array(all_images[i:i+window])
    reshaped_values= np.zeros((300,300,window))
    for i in range(window):
        reshaped_values[:,:,i]=temp[i,:,:]        
    
    training_x.append(reshaped_values)
    training_y.append(np.array(all_images[window + i +1]))

# %%
# training_x=[]
# training_y=[]
# window=20

# for iter in range(len(all_images)-1-window):
#   print("Preparing training data ", iter)
#   trining_data_temp=all_images[iter]
#   for i in range(1,window):
#     temp = all_images[iter+i]
#     trining_data_temp=np.stack([temp,trining_data_temp],axis=0)

#   training_x.append(trining_data_temp)
#   training_y.append(all_images[iter + i +1])

# %%
# training_x=np.array(training_x)
# training_y=np.array(training_y)
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y= train_test_split(np.array(training_x),np.array(training_y), test_size=0.2, shuffle=True, random_state=0)

# %%
train_x.shape
# Out:
# (577, 300, 300, 20)

# %% [raw]
# model= tf.keras.models.Sequential()
# model.add(layers.Conv3D(64,3,input_shape=(300,300,20,1),padding="same",activation="relu"))
# model.add(layers.MaxPool3D((1,1,2)))
# model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))
#
# model.add(layers.Conv3D(32,3,padding="same",activation="relu"))
# model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))
#
# model.add(layers.Conv3D(16,3,padding="same",activation="relu"))
# model.add(layers.MaxPool3D((1,1,2)))
# model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))
#
# model.add(layers.Conv3D(16,3,padding="same",activation="relu"))
# model.add(layers.MaxPool3D((1,1,2)))
# model.add(layers.BatchNormalization())
#
#
# model.add(layers.Conv3D(1,3,padding="same",activation="relu"))
# model.add(layers.MaxPool3D((1,1,2)))
# model.add(layers.BatchNormalization())
# model.add(layers.Lambda(lambda  x:x.reshape(300,300)))

# %%
model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_144 (Conv3D)         (None, 300, 300, 20, 64)  1792
#
#  max_pooling3d_52 (MaxPoolin  (None, 300, 300, 10, 64)  0
#  g3D)
#
#  batch_normalization_128 (Ba  (None, 300, 300, 10, 64)  256
#  tchNormalization)
#
#  dropout_87 (Dropout)        (None, 300, 300, 10, 64)  0
#
#  conv3d_145 (Conv3D)         (None, 300, 300, 10, 32)  55328
#
#  batch_normalization_129 (Ba  (None, 300, 300, 10, 32)  128
#  tchNormalization)
#
#  dropout_88 (Dropout)        (None, 300, 300, 10, 32)  0
#
#  conv3d_146 (Conv3D)         (None, 300, 300, 10, 16)  13840
#
#  max_pooling3d_53 (MaxPoolin  (None, 300, 300, 5, 16)  0
#  g3D)
#
#  batch_normalization_130 (Ba  (None, 300, 300, 5, 16)  64
#  tchNormalization)
#
#  dropout_89 (Dropout)        (None, 300, 300, 5, 16)   0
#
#  conv3d_147 (Conv3D)         (None, 300, 300, 5, 16)   6928
#
#  max_pooling3d_54 (MaxPoolin  (None, 300, 300, 2, 16)  0
#  g3D)
#
#  batch_normalization_131 (Ba  (None, 300, 300, 2, 16)  64
#  tchNormalization)
#
#  conv3d_148 (Conv3D)         (None, 300, 300, 2, 1)    433
#
#  max_pooling3d_55 (MaxPoolin  (None, 300, 300, 1, 1)   0
#  g3D)
#
#  batch_normalization_132 (Ba  (None, 300, 300, 1, 1)   4
#  tchNormalization)
#
#  lambda_7 (Lambda)           (300, 300, 1, 1)          0
#
# =================================================================
# Total params: 78,837
# Trainable params: 78,579
# Non-trainable params: 258
# _________________________________________________________________

# %%
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="mse",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["mse"],
)

# %%
epochs = 100
model.fit(
    x=train_x,y=train_y,batch_size=5,
#     validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
#     callbacks=[checkpoint_cb, early_stopping_cb],
)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [188], in <cell line: 2>()
#       1 epochs = 100
# ----> 2 model.fit(
#       3     x=train_x,y=train_y,batch_size=5,
#       4 #     validation_data=validation_dataset,
#       5     epochs=epochs,
#       6     shuffle=True,
#       7     verbose=2,
#       8 #     callbacks=[checkpoint_cb, early_stopping_cb],
#       9 )
#
# File ~\.conda\envs\myenv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/BroadcastGradientArgs' defined at (most recent call last):
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 2854, in run_cell
#       result = self._run_cell(
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 2900, in _run_cell
#       return runner(coro)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 3301, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 3361, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\hmdebern.UTMB-USERS-M\AppData\Local\Temp\ipykernel_20620\1922032315.py", line 2, in <cell line: 2>
#       model.fit(
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1384, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1021, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1010, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1000, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 863, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\optimizer_v2\optimizer_v2.py", line 530, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\optimizer_v2\optimizer_v2.py", line 583, in _compute_gradients
#       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\optimizer_v2\optimizer_v2.py", line 464, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/mean_squared_error/BroadcastGradientArgs'
# Incompatible shapes: [5,300,300,1,1] vs. [5,300,300]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]] [Op:__inference_train_function_11639]

# %%
# Construct the input layer with no definite frame size.
inp = layers.Input(shape=(train_x[0].shape))

# We will construct 3 `ConvLSTM2D` layers with batch normalization,
# followed by a `Conv3D` layer for the spatiotemporal outputs.
x = layers.ConvLSTM2D(
    filters=64,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="relu",
)(inp)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=64,
    kernel_size=(3, 3),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=64,
    kernel_size=(1, 1),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.Conv3D(
    filters=1, kernel_size=(3, 3, 3), activation="sigmoid", padding="same"
)(x)

# Next, we will build the complete model and compile it.
model = keras.models.Model(inp, x)
model.compile(
    loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(),
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 6>()
#       2 inp = layers.Input(shape=(train_x[0].shape))
#       4 # We will construct 3 `ConvLSTM2D` layers with batch normalization,
#       5 # followed by a `Conv3D` layer for the spatiotemporal outputs.
# ----> 6 x = layers.ConvLSTM2D(
#       7     filters=64,
#       8     kernel_size=(5, 5),
#       9     padding="same",
#      10     return_sequences=True,
#      11     activation="relu",
#      12 )(inp)
#      13 x = layers.BatchNormalization()(x)
#      14 x = layers.ConvLSTM2D(
#      15     filters=64,
#      16     kernel_size=(3, 3),
#    (...)
#      19     activation="relu",
#      20 )(x)
#
# File ~\.conda\envs\myenv\lib\site-packages\keras\layers\recurrent.py:679, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     673 inputs, initial_state, constants = _standardize_args(inputs,
#     674                                                      initial_state,
#     675                                                      constants,
#     676                                                      self._num_constants)
#     678 if initial_state is None and constants is None:
# --> 679   return super(RNN, self).__call__(inputs, **kwargs)
#     681 # If any of `initial_state` or `constants` are specified and are Keras
#     682 # tensors, then add them to the inputs and temporarily modify the
#     683 # input_spec to include them.
#     685 additional_inputs = []
#
# File ~\.conda\envs\myenv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\.conda\envs\myenv\lib\site-packages\keras\engine\input_spec.py:214, in assert_input_compatibility(input_spec, inputs, layer_name)
#     212   ndim = shape.rank
#     213   if ndim != spec.ndim:
# --> 214     raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#     215                      'is incompatible with the layer: '
#     216                      f'expected ndim={spec.ndim}, found ndim={ndim}. '
#     217                      f'Full shape received: {tuple(shape)}')
#     218 if spec.max_ndim is not None:
#     219   ndim = x.shape.rank
#
# ValueError: Input 0 of layer "conv_lstm2d_1" is incompatible with the layer: expected ndim=5, found ndim=4. Full shape received: (None, 20, 300, 300)

# %%
# Define some callbacks to improve training.
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

# Define modifiable training hyperparameters.
epochs = 20
batch_size = 5

# Fit the model to the training data.
model.fit(
    training_x,
    training_y,
    batch_size=batch_size,
    epochs=epochs,
#     validation_data=(x_val, y_val),
    callbacks=[early_stopping, reduce_lr],
)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 10>()
#       7 batch_size = 5
#       9 # Fit the model to the training data.
# ---> 10 model.fit(
#      11     training_x,
#      12     training_y,
#      13     batch_size=batch_size,
#      14     epochs=epochs,
#      15 #     validation_data=(x_val, y_val),
#      16     callbacks=[early_stopping, reduce_lr],
#      17 )
#
# File ~\.conda\envs\myenv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\.conda\envs\myenv\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\training.py", line 859, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\keras\engine\input_spec.py", line 200, in assert_input_compatibility
#         raise ValueError(f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#
#     ValueError: Layer "model" expects 1 input(s), but it received 724 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:1' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:2' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:3' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:4' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:5' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:6' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:7' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:8' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:9' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:10' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:11' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:12' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:13' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:14' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:15' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:16' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:17' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:18' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:19' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:20' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:21' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:22' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:23' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:24' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:25' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:26' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:27' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:28' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:29' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:30' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:31' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:32' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:33' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:34' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:35' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:36' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:37' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:38' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:39' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:40' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:41' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:42' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:43' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:44' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:45' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:46' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:47' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:48' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:49' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:50' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:51' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:52' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:53' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:54' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:55' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:56' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:57' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:58' shape=(5, 300, 80) dtype=uint8>, <tf.Tensor 'IteratorGetNext:59' shape=(5, 300, 80) dtype=uint8>, <tf.Ten ...

# %% [markdown]
# Prepare the training and testing dataset

# %%
training_x=[]
training_y=[]
window=20

for iter in range(0,589):
  print("Preparing training data ", iter)
  trining_data_temp=np.array(Image.open('./images/'+data.FileName[iter]))[:,:,1]
  for i in range(1,window):
    temp = np.array(Image.open('./images/'+data.FileName[i+iter]))[:,:,1]
    trining_data_temp=np.concatenate([temp,trining_data_temp],axis=1)

  training_x.append(trining_data_temp)
  training_y.append(np.array(Image.open('./images/'+data.FileName[i+1+iter]))[:,:,1])
# Out:
# Preparing training data  0
# Preparing training data  1
# Preparing training data  2
# Preparing training data  3
# Preparing training data  4
# Preparing training data  5
# Preparing training data  6
# Preparing training data  7
# Preparing training data  8
# Preparing training data  9
# Preparing training data  10
# Preparing training data  11
# Preparing training data  12
# Preparing training data  13
# Preparing training data  14
# Preparing training data  15
# Preparing training data  16
# Preparing training data  17
# Preparing training data  18
# Preparing training data  19
# Preparing training data  20
# Preparing training data  21
# Preparing training data  22
# Preparing training data  23
# Preparing training data  24
# Preparing training data  25
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File ~\.conda\envs\myenv\lib\site-packages\PIL\ImageFile.py:235, in ImageFile.load(self)
#     234 try:
# --> 235     s = read(self.decodermaxblock)
#     236 except (IndexError, struct.error) as e:
#     237     # truncated png/gif
#
# File ~\.conda\envs\myenv\lib\site-packages\PIL\PngImagePlugin.py:896, in PngImageFile.load_read(self, read_bytes)
#     894 self.fp.read(4)  # CRC
# --> 896 cid, pos, length = self.png.read()
#     898 if cid not in [b"IDAT", b"DDAT", b"fdAT"]:
#
# File ~\.conda\envs\myenv\lib\site-packages\PIL\PngImagePlugin.py:162, in ChunkStream.read(self)
#     161     pos = self.fp.tell()
# --> 162     length = i32(s)
#     164 if not is_cid(cid):
#
# File ~\.conda\envs\myenv\lib\site-packages\PIL\_binary.py:85, in i32be(c, o)
#      84 def i32be(c, o=0):
# ---> 85     return unpack_from(">I", c, o)[0]
#
# error: unpack_from requires a buffer of at least 4 bytes for unpacking 4 bytes at offset 0 (actual buffer size is 0)
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#      10   trining_data_temp=np.concatenate([temp,trining_data_temp],axis=1)
#      12 training_x.append(trining_data_temp)
# ---> 13 training_y.append(np.array(Image.open('./images/'+data.FileName[i+1+iter]))[:,:,1])
#
# File ~\.conda\envs\myenv\lib\site-packages\PIL\Image.py:675, in Image.__array__(self, dtype)
#     673     new["data"] = self.tobytes("raw", "L")
#     674 else:
# --> 675     new["data"] = self.tobytes()
#     677 return np.array(self._ArrayData(new), dtype)
#
# File ~\.conda\envs\myenv\lib\site-packages\PIL\Image.py:718, in Image.tobytes(self, encoder_name, *args)
#     715 if encoder_name == "raw" and args == ():
#     716     args = self.mode
# --> 718 self.load()
#     720 # unpack data
#     721 e = _getencoder(self.mode, encoder_name, args)
#
# File ~\.conda\envs\myenv\lib\site-packages\PIL\ImageFile.py:241, in ImageFile.load(self)
#     239         break
#     240     else:
# --> 241         raise OSError("image file is truncated") from e
#     243 if not s:  # truncated jpeg
#     244     if LOAD_TRUNCATED_IMAGES:
#
# OSError: image file is truncated

# %%
temp = np.array(Image.open('./images/prb-heat-map-1-2.png'))
temp1 = np.array(Image.open('./images/prb-heat-map-1-2.png'))

temp3=np.concatenate([temp,temp1],axis=2)
temp3.shape
# Out:
# (6155, 7075, 8)

# %%
temp1.shape
# Out:
# (6155, 7075, 4)

# %%
# the data  size is small 744, take 20% for test ing ~ 150 data points (image)
temp = Image.open('./images/prb-heat-map-1-2.png')
temp=np.array(temp)

# %%
temp[:,:,3].shape
# Out:
# (6155, 7075)

# %%
plt.imshow(temp[:,:,:4])
