# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler

#import warnings warnings.filterwarnings(‘ignore’)

from scipy import stats
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

# %%
# Set random seed to get the same result after each time running the code
tf.random.set_seed(1234)

# %%
# import dataset
from google.colab import files
uploaded = files.upload()
# PRB data
# Out:
#      <input type="file" id="files-f44f14a0-e22a-4b89-9414-7fc8dc95bb74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f44f14a0-e22a-4b89-9414-7fc8dc95bb74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving raw5.csv to raw5.csv

# %%
import io
from pandas import read_csv
from datetime import datetime
# load data
def parse(x):
	return datetime.strptime(x, '%Y %m %d %H')
dataset = read_csv(io.BytesIO(uploaded['raw5.csv']),  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.drop('No', axis=1, inplace=True)
# manually specify column names
#dataset.columns = ['PRB', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']

dataset.index.name = 'Date'
# mark all NA values with 0
dataset['PRB'].fillna(0, inplace=True)
# drop the first 24 hours
#dataset = dataset[24:]
# summarize first 5 rows
print(dataset.head(746))
# Out:
#                          PRB
# Date
# 2021-09-26 00:00:00  27.3289
# 2021-09-26 01:00:00  13.2736
# 2021-09-26 02:00:00   6.8261
# 2021-09-26 03:00:00   7.5867
# 2021-09-26 04:00:00   4.1775
# ...                      ...
# 2021-10-26 19:00:00  55.2459
# 2021-10-26 20:00:00  77.3903
# 2021-10-26 21:00:00  83.8344
# 2021-10-26 22:00:00  76.0199
# 2021-10-26 23:00:00  76.5892
#
# [744 rows x 1 columns]

# %%
# Data preprocessing
# Define a function to draw time_series plot
def timeseries (x_axis, y_axis, x_label):
    plt.figure(figsize = (10, 6))
    plt.plot(x_axis, y_axis, color = 'black')
    #plt.xlabel(x_label, {'fontsize': 12})
    plt.xlabel( x_label, {'fontsize': 12})  
    plt.ylabel('PRB usage ', {'fontsize': 12})
#dataset = df.copy()
#timeseries(dataset.index.hour, dataset['PRB'], 'Time (hour)')
timeseries(dataset.index, dataset['PRB'], 'Time (date)')
#dataset['day'] = dataset.index.day
#dataset_by_month = dataset.resample('M').sum()
#timeseries(dataset_by_month.index, dataset_by_month['PRB'], 'Time(month)')
#dataset['year'] = dataset.index.year
#dataset_by_year = dataset.resample('Y').sum()
#timeseries(dataset_by_year.index, dataset_by_year['PRB'], 'Time (month)')

# %%
df=dataset

# %%
# Split train data and test data
train_size = int(len(df)*0.9)

# Use iloc to select a number of rows
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

# %%
# Data transformation
scaler = MinMaxScaler().fit(train_data)

train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
# Create input dataset
def create_dataset (X, look_back = 1):
    Xs, ys = [], []
 
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
 
    return np.array(Xs), np.array(ys)
LOOK_BACK = 24
X_train, y_train = create_dataset(train_scaled,LOOK_BACK)
X_test, y_test = create_dataset(test_scaled,LOOK_BACK)
# Print data shape
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
# Out:
# X_train.shape:  (645, 24, 1)
# y_train.shape:  (645, 1)
# X_test.shape:  (51, 24, 1)
# y_test.shape:  (51, 1)

# %%
X_test[:33].shape
# Out:
# (33, 24, 1)

# %%
# Create BiLSTM model
def create_bilstm(units):
    model = Sequential()
    # Input layer
    model.add(Bidirectional(
              LSTM(units = units, return_sequences=True), 
              input_shape=(X_train.shape[1], X_train.shape[2])))
    # Hidden layer
    model.add(Bidirectional(LSTM(units = units)))
    model.add(Dense(1))
    #model.add(Dense(2))
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_bilstm = create_bilstm(64)
#model_bilstm = create_bilstm(128)
# Create GRU model
def create_gru(units):
    model = Sequential()
    # Input layer
    model.add(GRU (units = units, return_sequences = True, 
    input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(GRU(units = units)) 
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #model.add(Dense(units = 2)) 
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_gru = create_gru(64)
#model_gru = create_gru(128)

# Create LSTM model
def create_lstm(units):
    model = Sequential()
    # Input layer
    model.add(LSTM (units = units, return_sequences = True, 
    input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(LSTM(units = units)) 
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #model.add(Dense(units = 2)) 
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_lstm = create_lstm(64)
#model_lstm = create_lstm(128)

# %%
# Plot train loss and validation loss
def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                               patience = 10)
    history = model.fit(X_train, y_train, epochs = 50,  
                        validation_split = 0.2,
                        batch_size = 128, shuffle = False, 
                        callbacks = [early_stop])
    return history
history_gru = fit_model(model_gru)
history_bilstm = fit_model(model_bilstm)
history_lstm = fit_model(model_lstm)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 4s 199ms/step - loss: 0.1614 - val_loss: 0.0628
# Epoch 2/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0681 - val_loss: 0.0924
# Epoch 3/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0960 - val_loss: 0.0612
# Epoch 4/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0598 - val_loss: 0.0490
# Epoch 5/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0513 - val_loss: 0.0468
# Epoch 6/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0490 - val_loss: 0.0438
# Epoch 7/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0476 - val_loss: 0.0438
# Epoch 8/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0496 - val_loss: 0.0420
# Epoch 9/50
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0442 - val_loss: 0.0374
# Epoch 10/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0391 - val_loss: 0.0344
# Epoch 11/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0353 - val_loss: 0.0321
# Epoch 12/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0333 - val_loss: 0.0300
# Epoch 13/50
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0310 - val_loss: 0.0280
# Epoch 14/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0294 - val_loss: 0.0255
# Epoch 15/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0270 - val_loss: 0.0229
# Epoch 16/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0238 - val_loss: 0.0214
# Epoch 17/50
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0218 - val_loss: 0.0205
# Epoch 18/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0212 - val_loss: 0.0192
# Epoch 19/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0210 - val_loss: 0.0186
# Epoch 20/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0195 - val_loss: 0.0189
# Epoch 21/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0188 - val_loss: 0.0177
# Epoch 22/50
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0185 - val_loss: 0.0173
# Epoch 23/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0185 - val_loss: 0.0169
# Epoch 24/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0200 - val_loss: 0.0164
# Epoch 25/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0171 - val_loss: 0.0159
# Epoch 26/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0181 - val_loss: 0.0160
# Epoch 27/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0165 - val_loss: 0.0153
# Epoch 28/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0166 - val_loss: 0.0151
# Epoch 29/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0173 - val_loss: 0.0148
# Epoch 30/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0164 - val_loss: 0.0145
# Epoch 31/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0172 - val_loss: 0.0144
# Epoch 32/50
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0155 - val_loss: 0.0140
# Epoch 33/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0160 - val_loss: 0.0138
# Epoch 34/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0150 - val_loss: 0.0140
# Epoch 35/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0148 - val_loss: 0.0134
# Epoch 36/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0163 - val_loss: 0.0133
# Epoch 37/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0150 - val_loss: 0.0135
# Epoch 38/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0143 - val_loss: 0.0130
# Epoch 39/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0165 - val_loss: 0.0130
# Epoch 40/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0153 - val_loss: 0.0141
# Epoch 41/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0150 - val_loss: 0.0129
# Epoch 42/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0140 - val_loss: 0.0137
# Epoch 43/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0155 - val_loss: 0.0128
# Epoch 44/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0145 - val_loss: 0.0142
# Epoch 45/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0150 - val_loss: 0.0126
# Epoch 46/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0145 - val_loss: 0.0125
# Epoch 47/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0133 - val_loss: 0.0124
# Epoch 48/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0145 - val_loss: 0.0125
# Epoch 49/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 50/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0141 - val_loss: 0.0121
# Epoch 1/50
# 5/5 [==============================] - 7s 387ms/step - loss: 0.1251 - val_loss: 0.1248
# Epoch 2/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1040 - val_loss: 0.0543
# Epoch 3/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0566 - val_loss: 0.0544
# Epoch 4/50
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0512 - val_loss: 0.0455
# Epoch 5/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0465 - val_loss: 0.0510
# Epoch 6/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0486 - val_loss: 0.0423
# Epoch 7/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0391 - val_loss: 0.0353
# Epoch 8/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0338 - val_loss: 0.0326
# Epoch 9/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0308 - val_loss: 0.0327
# Epoch 10/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0298 - val_loss: 0.0300
# Epoch 11/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0262 - val_loss: 0.0262
# Epoch 12/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0234 - val_loss: 0.0257
# Epoch 13/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0226 - val_loss: 0.0258
# Epoch 14/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0218 - val_loss: 0.0234
# Epoch 15/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0201 - val_loss: 0.0224
# Epoch 16/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0192 - val_loss: 0.0216
# Epoch 17/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0184 - val_loss: 0.0200
# Epoch 18/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 19/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0162 - val_loss: 0.0178
# Epoch 20/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0152 - val_loss: 0.0163
# Epoch 21/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0141 - val_loss: 0.0150
# Epoch 22/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0129 - val_loss: 0.0135
# Epoch 23/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0117 - val_loss: 0.0122
# Epoch 24/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0107 - val_loss: 0.0112
# Epoch 25/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0099 - val_loss: 0.0110
# Epoch 26/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0096 - val_loss: 0.0116
# Epoch 27/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0098 - val_loss: 0.0120
# Epoch 28/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0099 - val_loss: 0.0112
# Epoch 29/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0094 - val_loss: 0.0109
# Epoch 30/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0091 - val_loss: 0.0111
# Epoch 31/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0093 - val_loss: 0.0108
# Epoch 32/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0093 - val_loss: 0.0110
# Epoch 33/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0092 - val_loss: 0.0108
# Epoch 34/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0093 - val_loss: 0.0110
# Epoch 35/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0097 - val_loss: 0.0107
# Epoch 36/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0091 - val_loss: 0.0109
# Epoch 37/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0092 - val_loss: 0.0103
# Epoch 38/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 39/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0087 - val_loss: 0.0105
# Epoch 40/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0088 - val_loss: 0.0103
# Epoch 41/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0086 - val_loss: 0.0104
# Epoch 42/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0087 - val_loss: 0.0102
# Epoch 43/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0086 - val_loss: 0.0102
# Epoch 44/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0085 - val_loss: 0.0101
# Epoch 45/50
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0085 - val_loss: 0.0106
# Epoch 46/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0088 - val_loss: 0.0099
# Epoch 47/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0085 - val_loss: 0.0103
# Epoch 48/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0086 - val_loss: 0.0107
# Epoch 49/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0089 - val_loss: 0.0105
# Epoch 50/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0095 - val_loss: 0.0114
# Epoch 1/50
# 5/5 [==============================] - 4s 216ms/step - loss: 0.1986 - val_loss: 0.0864
# Epoch 2/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0849 - val_loss: 0.1128
# Epoch 3/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1082 - val_loss: 0.0740
# Epoch 4/50
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0774 - val_loss: 0.0731
# Epoch 5/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0750 - val_loss: 0.0703
# Epoch 6/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0756 - val_loss: 0.0731
# Epoch 7/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0787 - val_loss: 0.0728
# Epoch 8/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0793 - val_loss: 0.0672
# Epoch 9/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0742 - val_loss: 0.0650
# Epoch 10/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0691 - val_loss: 0.0642
# Epoch 11/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0706 - val_loss: 0.0655
# Epoch 12/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0710 - val_loss: 0.0637
# Epoch 13/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0693 - val_loss: 0.0602
# Epoch 14/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0623 - val_loss: 0.0579
# Epoch 15/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0627 - val_loss: 0.0562
# Epoch 16/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0599 - val_loss: 0.0537
# Epoch 17/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0551 - val_loss: 0.0501
# Epoch 18/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0529 - val_loss: 0.0480
# Epoch 19/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0508 - val_loss: 0.0462
# Epoch 20/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0496 - val_loss: 0.0455
# Epoch 21/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0484 - val_loss: 0.0481
# Epoch 22/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0463 - val_loss: 0.0447
# Epoch 23/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0447 - val_loss: 0.0461
# Epoch 24/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0467 - val_loss: 0.0422
# Epoch 25/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0426 - val_loss: 0.0430
# Epoch 26/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0412 - val_loss: 0.0397
# Epoch 27/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0427 - val_loss: 0.0388
# Epoch 28/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0377 - val_loss: 0.0368
# Epoch 29/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0375 - val_loss: 0.0417
# Epoch 30/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0406 - val_loss: 0.0364
# Epoch 31/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0363 - val_loss: 0.0371
# Epoch 32/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0380 - val_loss: 0.0390
# Epoch 33/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0408 - val_loss: 0.0347
# Epoch 34/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0332 - val_loss: 0.0378
# Epoch 35/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0380 - val_loss: 0.0340
# Epoch 36/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0328 - val_loss: 0.0353
# Epoch 37/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0341 - val_loss: 0.0320
# Epoch 38/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0306 - val_loss: 0.0350
# Epoch 39/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0355 - val_loss: 0.0308
# Epoch 40/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0284 - val_loss: 0.0342
# Epoch 41/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0302 - val_loss: 0.0313
# Epoch 42/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0288 - val_loss: 0.0281
# Epoch 43/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0265 - val_loss: 0.0293
# Epoch 44/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0272 - val_loss: 0.0305
# Epoch 45/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0283 - val_loss: 0.0288
# Epoch 46/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0258 - val_loss: 0.0252
# Epoch 47/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0236 - val_loss: 0.0265
# Epoch 48/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0246 - val_loss: 0.0275
# Epoch 49/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0279 - val_loss: 0.0278
# Epoch 50/50
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0220 - val_loss: 0.0262

# %%
#Inverse transform of the target variable
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# %%
#Evaluate the models'performance
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
    #plt.savefig('C:/Users/yohannes.mulatu/Desktop/Thesis/figs/plots_'+ model_name + str(LOOK_BACK))
 
plot_loss (history_gru,'GRU')
plot_loss (history_bilstm, 'Bidirectional LSTM')
plot_loss (history_lstm, 'LSTM')

# %%
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction
prediction_gru = prediction(model_gru)
prediction_bilstm = prediction(model_bilstm)
prediction_lstm = prediction(model_lstm)
# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    plt.figure(figsize=(10, 6))
    range_future = len(prediction)
    plt.plot(np.arange(range_future), np.array(y_test), 
             label='Test   data')
    plt.plot(np.arange(range_future), 
             np.array(prediction),label='Prediction')
    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PRB percentage Usage')
 
plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_bilstm, 'Bidirectional LSTM', y_test)
plot_future(prediction_lstm, 'LSTM', y_test)

# %%
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    mape = np.mean(np.abs((actual- predictions)/actual))*100
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('Mean Absolute Percentage Error: {:.4f}'.format(mape))
    print('')
evaluate_prediction(prediction_gru, y_test, 'GRU')
evaluate_prediction(prediction_bilstm, y_test, 'Bidirectiona LSTM')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
# Out:
# GRU:
# Mean Absolute Error: 2023.8994
# Root Mean Square Error: 2300.2774
# Mean Absolute Percentage Error: 113.2471
#
# Bidirectiona LSTM:
# Mean Absolute Error: 688.0993
# Root Mean Square Error: 869.3516
# Mean Absolute Percentage Error: 27.1589
#
# LSTM:
# Mean Absolute Error: 2023.9608
# Root Mean Square Error: 2300.3964
# Mean Absolute Percentage Error: 113.2284

# %%
# Multi-step forecasting
# select 30 days of data from the test data
#new_data = test_data.iloc[100:160]
#new_data = test_data.iloc[57:69]
new_data = test_data.iloc[:]
#print(new_data.head(5))
# scale the input
scaled_data =scaler.transform(new_data)
# Reshape the input
def create_dataset (X,look_back =1):
      Xs = []
      for i in range (len(X) - look_back):
          v = X[i:i+look_back] 
          Xs.append(v)

      return np.array(Xs)
X_6= create_dataset(scaled_data, 6)   
print('X_6.shape: ', X_6.shape)
# Out:
# X_6.shape:  (69, 6, 1)

# %%
# Make prediction for new data

def prediction(model):
    prediction = model.predict(X_6)
    prediction = scaler.inverse_transform(prediction)
    return prediction
prediction_gru = prediction(model_gru)
prediction_bilstm = prediction(model_bilstm)
prediction_lstm = prediction(model_lstm)
# Plot history and future
def plot_multi_step(history, prediction1, prediction2,prediction3):
    
    plt.figure(figsize=(15, 6))
    
    range_history = len(history)
    range_future = list(range(range_history, range_history +
                        len(prediction1)))
    plt.plot(np.arange(range_history), np.array(history), 
              label='History')
    plt.plot(range_future, np.array(prediction1),
             label='Forecasted for GRU')
    plt.plot(range_future, np.array(prediction2),
             label='Forecasted for BiLSTM')
    plt.plot(range_future, np.array(prediction3),
             label='Forecasted for LSTM')
      
    plt.legend(loc='upper left')
    plt.xlabel('Time step (day)')
    plt.ylabel('PRB % Usage')
        
plot_multi_step(new_data, prediction_gru, prediction_bilstm,prediction_lstm)
